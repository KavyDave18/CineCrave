# %%
from sentence_transformers import SentenceTransformer
import pickle
import numpy as np

# %%
import pandas as pd

# %%
movies_clean = pd.read_csv("../data/movies_cleaned.csv")

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")

# %%
content_list = movies_clean['content'].tolist()

# %%
embeddings = model.encode(
    content_list,
    show_progress_bar = True
)
# Out:
# Batches: 100%|████████████████████████████████| 151/151 [00:17<00:00,  8.47it/s]

# %%
print(type(embeddings))
# Out:
# <class 'numpy.ndarray'>

# %%
print(embeddings.shape)
# Out:
# (4803, 384)

# %%
print(len(embeddings))
# Out:
# 4803

# %%
print(len(movies_clean))
# Out:
# 4803

# %%
print(len(embeddings[0]))
# Out:
# 384

# %%
print(embeddings[0])
# Out:
# [-2.57971194e-02 -3.32936086e-02  7.60778878e-03 -5.29247634e-02
#  -7.71878585e-02  2.50345841e-02 -5.00053866e-03 -8.51928815e-02
#   2.70986073e-02  1.50026577e-02  2.92691849e-02 -5.49177863e-02
#  -1.10469852e-02  3.20897065e-02 -3.22754867e-02  6.44825175e-02
#  -1.27119962e-02  1.00140469e-02  1.05573609e-02  6.07281625e-02
#  -4.21410613e-02  3.16623077e-02 -5.25368452e-02  3.63436639e-02
#  -3.60980816e-02  3.88724171e-02  6.25832528e-02 -6.65085576e-03
#  -8.43190402e-02  3.35503034e-02 -6.40532672e-02  1.55829534e-01
#  -8.40990841e-02  3.36101055e-02  1.39775835e-02  1.13686644e-01
#  -2.96652298e-02 -5.57777025e-02  2.82413010e-02 -1.51874153e-02
#  -8.74765217e-02 -1.10513069e-01  3.83488052e-02 -2.28110850e-02
#  -5.61962910e-02 -1.35707617e-01 -5.92456479e-03 -7.86024258e-02
#   8.56946036e-02 -1.11344969e-02 -9.91751552e-02 -3.06938514e-02
#  -6.39107600e-02  2.19990537e-02  3.18171717e-02 -1.21638991e-01
#  -4.76740375e-02  4.71041016e-02 -7.53745111e-03 -1.43682778e-01
#  -3.87970805e-02 -1.10247582e-02  7.35774636e-02 -2.02921592e-02
#  -1.63643956e-02 -1.66667253e-02 -1.24415979e-02  1.63918436e-02
#   2.62960810e-02 -6.41033128e-02 -3.78953740e-02  2.68359436e-03
#   6.65436592e-03 -3.20576578e-02 -2.46222634e-02  5.00453226e-02
#   4.68892641e-02  3.73016484e-03  3.99732729e-03 -8.71705785e-02
#   1.12677634e-01 -3.94797977e-03 -5.55287413e-02  4.32565212e-02
#  -2.51323450e-02  2.79414877e-02  1.13444338e-02  3.46996672e-02
#  -1.47848753e-02  5.82453124e-02 -6.30430877e-02 -6.17733486e-02
#   5.78228608e-02 -1.93144493e-02 -6.69958219e-02 -1.41645316e-02
#  -6.85263723e-02  3.34574166e-03 -5.32080866e-02  3.60345282e-02
#   6.23655207e-02  2.88876034e-02  1.39072901e-02 -4.25013853e-03
#   5.93104400e-02 -7.56767094e-02  5.69550656e-02 -6.85819164e-02
#  -2.94852536e-02 -2.15755794e-02 -4.54206914e-02  2.77857687e-02
#  -1.04771987e-01  2.00131834e-02 -1.73982717e-02  7.03400671e-02
#  -3.85355055e-02  1.40740285e-02  4.60884012e-02  2.46576332e-02
#   4.98952996e-03 -7.63270035e-02 -9.40606073e-02 -4.68948099e-04
#  -4.81239334e-03 -2.36432850e-02 -4.06871177e-02  1.64811449e-32
#   4.12988476e-02 -1.66015737e-02  5.80694117e-02  1.54220741e-02
#   1.48102194e-02 -8.96671638e-02  2.19773166e-02  6.50927201e-02
#   3.69660854e-02  1.17800124e-02 -4.71489504e-02  4.39103916e-02
#  -1.82486996e-02  1.17107369e-01 -1.14383027e-02  1.15766577e-01
#  -7.51852766e-02  3.64198089e-02  1.29737621e-02  1.31299542e-02
#  -3.75092588e-02  1.24521768e-02  1.63064152e-03 -5.54616228e-08
#   2.70517785e-02  3.10333036e-02 -6.23729499e-03  3.83444130e-02
#  -1.70036238e-02  2.74192989e-02  1.12890955e-02  5.32821529e-02
#  -2.60968916e-02  9.31262821e-02 -4.63710651e-02 -3.48988622e-02
#   1.84485000e-02 -2.65158638e-02  2.13086661e-02  2.03500781e-02
#   3.71997021e-02  6.85455352e-02 -6.11585826e-02  3.05641256e-03
#   1.32366801e-02  8.50301236e-03  8.50279257e-02 -8.20347667e-02
#  -2.70512160e-02  1.34321764e-01  1.83752831e-02 -4.58764881e-02
#  -1.16890727e-03  4.36845608e-02  1.74128935e-02  2.72742286e-02
#  -1.13768496e-01 -1.23248389e-02 -9.52614546e-02 -4.03314717e-02
#  -1.63642701e-03  1.99287687e-03 -2.78495755e-02 -6.43517403e-03
#   5.82562797e-02  6.55165911e-02 -4.16812189e-02  6.51485026e-02
#   6.06844649e-02  6.53921887e-02  1.17245100e-01 -4.40009050e-02
#   1.75614550e-03 -3.18183750e-02  2.09219716e-02 -3.28201056e-02
#   4.13832739e-02  1.19672678e-02  1.42966257e-02  8.58479068e-02
#  -2.20812019e-02  1.28447786e-01 -1.58498324e-02  4.79346067e-02
#   2.07352061e-02  6.64794724e-03 -5.27637592e-03 -2.20504799e-03]

# %%
with open("movies_embeddings.pkl" , "wb") as f:
    pickle.dump(embeddings,f)

# %%
with open("movie_index.pkl", "wb") as f:
    pickle.dump(
        movies_clean[['original_title']],
        f
    )

# %%
with open("movies_embeddings.pkl" , "rb") as f:
    embedding = pickle.load(f)

# %%
print(embedding.shape)
# Out:
# (4803, 384)

# %%
with open("movie_index.pkl" , "rb") as f:
    movie_index = pickle.load(f)

# %%
title_to_index = {}
for idx,title in enumerate(movie_index['original_title']):
    title_to_index[title.lower()] = idx

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %% [markdown]
# ## Final Recommend Func

# %%
def recommend(movie_name,top_n=5):
    
    if not isinstance(movie_name,str):
        return "Input Invalid , Movie name must be a string..."
        
    movie_name = movie_name.lower()

    if movie_name not in title_to_index:
        return "Movie not Found"

    idx = title_to_index[movie_name]

    query_vector = embedding[idx].reshape(1,-1)

    similarity_scores = cosine_similarity(query_vector,embedding)[0]

    similar_indices = np.argsort(similarity_scores)[::-1][1:top_n+1]

    return [
        movie_index.iloc[i]['original_title']
        for i in similar_indices
    ]

# %%
recommend("Avatar")
# Out:
# ['Serenity',
#  'Aliens',
#  'Star Trek Beyond',
#  'Barbarella',
#  'Star Trek Into Darkness']

# %%
recommend("interstellar")
# Out:
# ['Prometheus',
#  'Mission to Mars',
#  'Red Planet',
#  'Tomorrowland',
#  'Obitaemyy Ostrov']

# %%
# %time recommend("Avatar")
# Out:
# CPU times: user 8.12 ms, sys: 3.13 ms, total: 11.2 ms
# Wall time: 8.98 ms
# ['Serenity',
#  'Aliens',
#  'Star Trek Beyond',
#  'Barbarella',
#  'Star Trek Into Darkness']

# %%
recommend("random junk")
# Out:
# 'Movie not Found'
