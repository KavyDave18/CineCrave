# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(
    max_features = 5000,
    stop_words = 'english'
)

# %%
df = pd.read_csv('../data/movies_cleaned.csv')

# %%
df.head()
# Out:
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  \
# 0  in the 22nd century a paraplegic marine is dis...
# 1  captain barbossa long believed to be dead has ...
# 2  a cryptic message from bonds past sends him on...
# 3  following the death of district attorney harve...
# 4  john carter is a warweary former military capt...
#
#                                      genres  \
# 0  action adventure fantasy science fiction
# 1                  adventure fantasy action
# 2                    action adventure crime
# 3               action crime drama thriller
# 4          action adventure science fiction
#
#                                             keywords  \
# ...

# %%
df['content'].head()
# Out:
# 0    in the 22nd century a paraplegic marine is dis...
# 1    captain barbossa long believed to be dead has ...
# 2    a cryptic message from bonds past sends him on...
# 3    following the death of district attorney harve...
# 4    john carter is a warweary former military capt...
# Name: content, dtype: object

# %%
tfidf_matrix = tfidf.fit_transform(df['content'])

# %%
tfidf_matrix.shape
# Out:
# (4803, 5000)

# %%
type(tfidf_matrix)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
tfidf.get_feature_names_out()
# Out:
# array(['007', '10', '10yearold', ..., 'zoo', 'zooey', 'zucker'],
#       dtype=object)

# %%
 tfidf_matrix[0]
# Out:
# <1x5000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 49 stored elements in Compressed Sparse Row format>

# %%
movie_vectors = tfidf_matrix
vectorizer = tfidf

# %% [markdown]
# ## DAY_4 -> Similarity_Engine

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_matrix = cosine_similarity(tfidf_matrix)

# %%
similarity_matrix.shape
# Out:
# (4803, 4803)

# %%
import pandas as pd

# %%
movie_indices = pd.Series(
    df.index,
    index = df['original_title']
)

# %%
movie_indices['Avatar']
# Out:
# 0

# %% [markdown]
# ## USER SELECTS AVATAR

# %%
idx = movie_indices['Avatar']

# %%
similarity_scores = list(enumerate(similarity_matrix[idx]))

# %%
similarity_scores = sorted(
    similarity_scores,
    key = lambda x:x[1],
    reverse = True
)

# %%
top_similar_movies = similarity_score[1:6]

# %%
recommended_movies = []

# %%
for movie in top_similar_movies:
    movie_idx = movie[0]
    recommended_movies.append(df.iloc[movie_idx].original_title)

# %%
recommended_movies
# Out:
# ["Pirates of the Caribbean: At World's End",
#  'Spectre',
#  'The Dark Knight Rises',
#  'John Carter',
#  'Spider-Man 3']
